# %% [markdown]
# Based on the [VGGFace Baseline 197X197](https://www.kaggle.com/hsinwenchang/vggface-baseline-197x197)  kernel

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['test', 'train_relationships.csv', 'train', 'sample_submission.csv']

# %%
from collections import defaultdict
from glob import glob
from random import choice, sample
from keras.preprocessing import image
import cv2
import numpy as np
import pandas as pd
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Input, Dense, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract
from keras.models import Model
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
# !pip install git+https://github.com/rcmalli/keras-vggface.git
# Out:
# Collecting git+https://github.com/rcmalli/keras-vggface.git
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-izvrkg_z
#   Running command git clone -q https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-izvrkg_z
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.6) (1.16.4)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.6) (1.2.1)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.6) (2.9.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.6) (5.4.1)
# Requirement already satisfied: keras in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.6) (2.2.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.6) (1.12.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.6) (5.1.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.6/site-packages (from keras->keras-vggface==0.6) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.6/site-packages (from keras->keras-vggface==0.6) (1.1.0)
# Building wheels for collected packages: keras-vggface
# done
#   Created wheel for keras-vggface: filename=keras_vggface-0.6-cp36-none-any.whl size=8311 sha256=f29d11751acc86b385c3c5acf550af1796b8a0989562ce18817a9a580e1631d5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-geqk5ei6/wheels/36/07/46/06c25ce8e9cd396dabe151ea1d8a2bc28dafcb11321c1f3a6d
# Successfully built keras-vggface
# Installing collected packages: keras-vggface
# Successfully installed keras-vggface-0.6

# %%
from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

# %%
train_file_path = "../input/train_relationships.csv"
train_folders_path = "../input/train/"
val_famillies = "F09"

all_images = glob(train_folders_path + "*/*/*.jpg")

train_images = [x for x in all_images if val_famillies not in x]
val_images = [x for x in all_images if val_famillies in x]

train_person_to_images_map = defaultdict(list)

ppl = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images]

for x in train_images:
    train_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

val_person_to_images_map = defaultdict(list)

for x in val_images:
    val_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

# %%
relationships = pd.read_csv(train_file_path)
relationships = list(zip(relationships.p1.values, relationships.p2.values))
relationships = [x for x in relationships if x[0] in ppl and x[1] in ppl]

train = [x for x in relationships if val_famillies not in x[0]]
val = [x for x in relationships if val_famillies in x[0]]

# %%
def read_img(path):
    img = image.load_img(path, target_size=(224, 224))
    img = np.array(img).astype(np.float)
    return preprocess_input(img, version=2)

def gen(list_tuples, person_to_images_map, batch_size=16):
    ppl = list(person_to_images_map.keys())
    while True:
        batch_tuples = sample(list_tuples, batch_size // 2)
        labels = [1] * len(batch_tuples)
        while len(batch_tuples) < batch_size:
            p1 = choice(ppl)
            p2 = choice(ppl)

            if p1 != p2 and (p1, p2) not in list_tuples and (p2, p1) not in list_tuples:
                batch_tuples.append((p1, p2))
                labels.append(0)

        for x in batch_tuples:
            if not len(person_to_images_map[x[0]]):
                print(x[0])

        X1 = [choice(person_to_images_map[x[0]]) for x in batch_tuples]
        X1 = np.array([read_img(x) for x in X1])

        X2 = [choice(person_to_images_map[x[1]]) for x in batch_tuples]
        X2 = np.array([read_img(x) for x in X2])

        yield [X1, X2], labels


def baseline_model():
    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

    base_model = VGGFace(model='resnet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)

#     x1_ = Reshape(target_shape=(7*7, 2048))(x1)
#     x2_ = Reshape(target_shape=(7*7, 2048))(x2)
#     #
#     x_dot = Dot(axes=[2, 2], normalize=True)([x1_, x2_])
#     x_dot = Flatten()(x_dot)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x3 = Subtract()([x1, x2])
    x3 = Multiply()([x3, x3])

    x1_ = Multiply()([x1, x1])
    x2_ = Multiply()([x2, x2])
    x4 = Subtract()([x1_, x2_])
    
    x5 = Multiply()([x1, x2])
    
    x = Concatenate(axis=-1)([x4, x3, x5])

    x = Dense(100, activation="relu")(x)
    x = Dropout(0.01)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
file_path = "vgg_face.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

callbacks_list = [checkpoint, reduce_on_plateau]

model = baseline_model()
#model.load_weights(file_path)
model.fit_generator(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=150, verbose=2,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=200, validation_steps=100)
# Out:
# Downloading data from https://github.com/rcmalli/keras-vggface/releases/download/v2.0/rcmalli_vggface_tf_notop_resnet50.h5
# 94699520/94694792 [==============================] - 1s 0us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# vggface_resnet50 (Model)        multiple             23561152    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 2048)         0           vggface_resnet50[2][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           vggface_resnet50[2][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4096)         0           global_max_pooling2d_1[0][0]
#                                                                  global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4096)         0           global_max_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 4096)         0           concatenate_1[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 4096)         0           concatenate_2[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 4096)         0           concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 4096)         0           multiply_2[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4096)         0           subtract_1[0][0]
#                                                                  subtract_1[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 4096)         0           concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 12288)        0           subtract_2[0][0]
#                                                                  multiply_1[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          1228900     concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            101         dropout_1[0][0]
# ==================================================================================================
# Total params: 24,790,153
# Trainable params: 24,737,033
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Epoch 1/150
# /opt/conda/lib/python3.6/site-packages/keras/engine/training_generator.py:47: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
#  - 109s - loss: 3.5824 - acc: 0.5734 - val_loss: 3.6318 - val_acc: 0.5931
#
# Epoch 00001: val_acc improved from -inf to 0.59313, saving model to vgg_face.h5
# Epoch 2/150
#  - 80s - loss: 2.1135 - acc: 0.6441 - val_loss: 2.7235 - val_acc: 0.5875
#
# Epoch 00002: val_acc did not improve from 0.59313
# Epoch 3/150
#  - 79s - loss: 1.2160 - acc: 0.6897 - val_loss: 1.8269 - val_acc: 0.6300
#
# Epoch 00003: val_acc improved from 0.59313 to 0.63000, saving model to vgg_face.h5
# Epoch 4/150
#  - 78s - loss: 0.8489 - acc: 0.7006 - val_loss: 0.9137 - val_acc: 0.6863
#
# Epoch 00004: val_acc improved from 0.63000 to 0.68625, saving model to vgg_face.h5
# Epoch 5/150
#  - 80s - loss: 0.6097 - acc: 0.7363 - val_loss: 0.7221 - val_acc: 0.7094
#
# Epoch 00005: val_acc improved from 0.68625 to 0.70937, saving model to vgg_face.h5
# Epoch 6/150
#  - 77s - loss: 0.5277 - acc: 0.7587 - val_loss: 0.6500 - val_acc: 0.7306
#
# Epoch 00006: val_acc improved from 0.70937 to 0.73062, saving model to vgg_face.h5
# Epoch 7/150
#  - 76s - loss: 0.5056 - acc: 0.7650 - val_loss: 0.6256 - val_acc: 0.7281
#
# Epoch 00007: val_acc did not improve from 0.73062
# Epoch 8/150
#  - 78s - loss: 0.4649 - acc: 0.7812 - val_loss: 0.5987 - val_acc: 0.7362
#
# Epoch 00008: val_acc improved from 0.73062 to 0.73625, saving model to vgg_face.h5
# Epoch 9/150
#  - 78s - loss: 0.4673 - acc: 0.7775 - val_loss: 0.6426 - val_acc: 0.7438
#
# Epoch 00009: val_acc improved from 0.73625 to 0.74375, saving model to vgg_face.h5
# Epoch 10/150
#  - 78s - loss: 0.4665 - acc: 0.7834 - val_loss: 0.5109 - val_acc: 0.7612
#
# Epoch 00010: val_acc improved from 0.74375 to 0.76125, saving model to vgg_face.h5
# Epoch 11/150
#  - 79s - loss: 0.4250 - acc: 0.7956 - val_loss: 0.5479 - val_acc: 0.7444
#
# Epoch 00011: val_acc did not improve from 0.76125
# Epoch 12/150
#  - 79s - loss: 0.4265 - acc: 0.8019 - val_loss: 0.4627 - val_acc: 0.7675
#
# Epoch 00012: val_acc improved from 0.76125 to 0.76750, saving model to vgg_face.h5
# Epoch 13/150
#  - 78s - loss: 0.4076 - acc: 0.8056 - val_loss: 0.5348 - val_acc: 0.7612
#
# Epoch 00013: val_acc did not improve from 0.76750
# Epoch 14/150
#  - 79s - loss: 0.4224 - acc: 0.8038 - val_loss: 0.5115 - val_acc: 0.7494
#
# Epoch 00014: val_acc did not improve from 0.76750
# Epoch 15/150
#  - 79s - loss: 0.3948 - acc: 0.8241 - val_loss: 0.4780 - val_acc: 0.7719
#
# Epoch 00015: val_acc improved from 0.76750 to 0.77187, saving model to vgg_face.h5
# Epoch 16/150
#  - 77s - loss: 0.3723 - acc: 0.8372 - val_loss: 0.4903 - val_acc: 0.7756
#
# Epoch 00016: val_acc improved from 0.77187 to 0.77563, saving model to vgg_face.h5
# Epoch 17/150
#  - 77s - loss: 0.3705 - acc: 0.8322 - val_loss: 0.6036 - val_acc: 0.7638
#
# Epoch 00017: val_acc did not improve from 0.77563
# Epoch 18/150
#  - 78s - loss: 0.3551 - acc: 0.8394 - val_loss: 0.7079 - val_acc: 0.7612
#
# Epoch 00018: val_acc did not improve from 0.77563
# Epoch 19/150
#  - 78s - loss: 0.3719 - acc: 0.8313 - val_loss: 0.5391 - val_acc: 0.7681
#
# Epoch 00019: val_acc did not improve from 0.77563
# Epoch 20/150
#  - 78s - loss: 0.3618 - acc: 0.8387 - val_loss: 0.5202 - val_acc: 0.7619
#
# Epoch 00020: val_acc did not improve from 0.77563
# Epoch 21/150
#  - 78s - loss: 0.3517 - acc: 0.8475 - val_loss: 0.5048 - val_acc: 0.7863
#
# Epoch 00021: val_acc improved from 0.77563 to 0.78625, saving model to vgg_face.h5
# Epoch 22/150
#  - 77s - loss: 0.3369 - acc: 0.8534 - val_loss: 0.4799 - val_acc: 0.7944
#
# Epoch 00022: val_acc improved from 0.78625 to 0.79438, saving model to vgg_face.h5
# Epoch 23/150
#  - 77s - loss: 0.3252 - acc: 0.8512 - val_loss: 0.5124 - val_acc: 0.7719
#
# Epoch 00023: val_acc did not improve from 0.79438
# Epoch 24/150
#  - 78s - loss: 0.3336 - acc: 0.8481 - val_loss: 0.5076 - val_acc: 0.7950
#
# Epoch 00024: val_acc improved from 0.79438 to 0.79500, saving model to vgg_face.h5
# Epoch 25/150
#  - 77s - loss: 0.3212 - acc: 0.8572 - val_loss: 0.5272 - val_acc: 0.7606
#
# Epoch 00025: val_acc did not improve from 0.79500
# Epoch 26/150
#  - 78s - loss: 0.3197 - acc: 0.8634 - val_loss: 0.4853 - val_acc: 0.7987
#
# Epoch 00026: val_acc improved from 0.79500 to 0.79875, saving model to vgg_face.h5
# Epoch 27/150
#  - 78s - loss: 0.3166 - acc: 0.8638 - val_loss: 0.4978 - val_acc: 0.7788
#
# Epoch 00027: val_acc did not improve from 0.79875
# Epoch 28/150
#  - 78s - loss: 0.3353 - acc: 0.8569 - val_loss: 0.5380 - val_acc: 0.7556
#
# Epoch 00028: val_acc did not improve from 0.79875
# Epoch 29/150
#  - 79s - loss: 0.3024 - acc: 0.8681 - val_loss: 0.4860 - val_acc: 0.7856
#
# Epoch 00029: val_acc did not improve from 0.79875
# Epoch 30/150
#  - 78s - loss: 0.2873 - acc: 0.8703 - val_loss: 0.4923 - val_acc: 0.7925
#
# Epoch 00030: val_acc did not improve from 0.79875
# Epoch 31/150
#  - 78s - loss: 0.3176 - acc: 0.8659 - val_loss: 0.5186 - val_acc: 0.7606
#
# Epoch 00031: val_acc did not improve from 0.79875
# Epoch 32/150
#  - 78s - loss: 0.2833 - acc: 0.8772 - val_loss: 0.4698 - val_acc: 0.8100
#
# Epoch 00032: val_acc improved from 0.79875 to 0.81000, saving model to vgg_face.h5
# Epoch 33/150
#  - 78s - loss: 0.2901 - acc: 0.8697 - val_loss: 0.6127 - val_acc: 0.7525
#
# Epoch 00033: val_acc did not improve from 0.81000
# Epoch 34/150
#  - 79s - loss: 0.2670 - acc: 0.8916 - val_loss: 0.4956 - val_acc: 0.7619
#
# Epoch 00034: val_acc did not improve from 0.81000
# Epoch 35/150
#  - 78s - loss: 0.2868 - acc: 0.8712 - val_loss: 0.5451 - val_acc: 0.7769
#
# Epoch 00035: val_acc did not improve from 0.81000
# Epoch 36/150
#  - 78s - loss: 0.2844 - acc: 0.8800 - val_loss: 0.5099 - val_acc: 0.7781
#
# Epoch 00036: val_acc did not improve from 0.81000
# Epoch 37/150
#  - 79s - loss: 0.2731 - acc: 0.8825 - val_loss: 0.5226 - val_acc: 0.7700
#
# Epoch 00037: val_acc did not improve from 0.81000
# Epoch 38/150
#  - 77s - loss: 0.2599 - acc: 0.8894 - val_loss: 0.5129 - val_acc: 0.7975
#
# Epoch 00038: val_acc did not improve from 0.81000
# Epoch 39/150
#  - 78s - loss: 0.2739 - acc: 0.8850 - val_loss: 0.5377 - val_acc: 0.7719
#
# Epoch 00039: val_acc did not improve from 0.81000
# Epoch 40/150
#  - 78s - loss: 0.2442 - acc: 0.8969 - val_loss: 0.4861 - val_acc: 0.7894
#
# Epoch 00040: val_acc did not improve from 0.81000
# Epoch 41/150
#  - 79s - loss: 0.2742 - acc: 0.8837 - val_loss: 0.5222 - val_acc: 0.7450
#
# Epoch 00041: val_acc did not improve from 0.81000
# Epoch 42/150
#  - 78s - loss: 0.2591 - acc: 0.8887 - val_loss: 0.5329 - val_acc: 0.7881
#
# Epoch 00042: val_acc did not improve from 0.81000
# Epoch 43/150
#  - 78s - loss: 0.2416 - acc: 0.8975 - val_loss: 0.5445 - val_acc: 0.7775
#
# Epoch 00043: val_acc did not improve from 0.81000
# Epoch 44/150
#  - 78s - loss: 0.2506 - acc: 0.8944 - val_loss: 0.5887 - val_acc: 0.7562
#
# Epoch 00044: val_acc did not improve from 0.81000
# Epoch 45/150
#  - 78s - loss: 0.2318 - acc: 0.9034 - val_loss: 0.5444 - val_acc: 0.7762
#
# Epoch 00045: val_acc did not improve from 0.81000
# Epoch 46/150
#  - 77s - loss: 0.2571 - acc: 0.8966 - val_loss: 0.5908 - val_acc: 0.7475
#
# Epoch 00046: val_acc did not improve from 0.81000
# Epoch 47/150
#  - 77s - loss: 0.2310 - acc: 0.9069 - val_loss: 0.5908 - val_acc: 0.7506
#
# Epoch 00047: val_acc did not improve from 0.81000
# Epoch 48/150
#  - 79s - loss: 0.2354 - acc: 0.9038 - val_loss: 0.5633 - val_acc: 0.7606
#
# Epoch 00048: val_acc did not improve from 0.81000
# Epoch 49/150
#  - 77s - loss: 0.2219 - acc: 0.9091 - val_loss: 0.5374 - val_acc: 0.7719
#
# Epoch 00049: val_acc did not improve from 0.81000
# Epoch 50/150
#  - 78s - loss: 0.2298 - acc: 0.9038 - val_loss: 0.6523 - val_acc: 0.7488
#
# Epoch 00050: val_acc did not improve from 0.81000
# Epoch 51/150
#  - 78s - loss: 0.2443 - acc: 0.8934 - val_loss: 0.5466 - val_acc: 0.7619
#
# Epoch 00051: val_acc did not improve from 0.81000
# Epoch 52/150
#  - 80s - loss: 0.2110 - acc: 0.9141 - val_loss: 0.5690 - val_acc: 0.7669
#
# Epoch 00052: val_acc did not improve from 0.81000
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 53/150
#  - 77s - loss: 0.2178 - acc: 0.9116 - val_loss: 0.5824 - val_acc: 0.7706
#
# Epoch 00053: val_acc did not improve from 0.81000
# Epoch 54/150
#  - 79s - loss: 0.1901 - acc: 0.9209 - val_loss: 0.5523 - val_acc: 0.7625
#
# Epoch 00054: val_acc did not improve from 0.81000
# Epoch 55/150
#  - 79s - loss: 0.2084 - acc: 0.9194 - val_loss: 0.6140 - val_acc: 0.7569
#
# Epoch 00055: val_acc did not improve from 0.81000
# Epoch 56/150
#  - 79s - loss: 0.1934 - acc: 0.9281 - val_loss: 0.5849 - val_acc: 0.7619
#
# Epoch 00056: val_acc did not improve from 0.81000
# Epoch 57/150
#  - 77s - loss: 0.1909 - acc: 0.9250 - val_loss: 0.6581 - val_acc: 0.7419
#
# Epoch 00057: val_acc did not improve from 0.81000
# Epoch 58/150
#  - 78s - loss: 0.1817 - acc: 0.9316 - val_loss: 0.5569 - val_acc: 0.7719
#
# Epoch 00058: val_acc did not improve from 0.81000
# Epoch 59/150
#  - 79s - loss: 0.1856 - acc: 0.9288 - val_loss: 0.6033 - val_acc: 0.7569
#
# Epoch 00059: val_acc did not improve from 0.81000
# Epoch 60/150
#  - 79s - loss: 0.1908 - acc: 0.9250 - val_loss: 0.6301 - val_acc: 0.7488
#
# Epoch 00060: val_acc did not improve from 0.81000
# Epoch 61/150
#  - 78s - loss: 0.1729 - acc: 0.9319 - val_loss: 0.5884 - val_acc: 0.7688
#
# Epoch 00061: val_acc did not improve from 0.81000
# Epoch 62/150
#  - 78s - loss: 0.1661 - acc: 0.9366 - val_loss: 0.6219 - val_acc: 0.7688
#
# Epoch 00062: val_acc did not improve from 0.81000
# Epoch 63/150
#  - 78s - loss: 0.1652 - acc: 0.9366 - val_loss: 0.6529 - val_acc: 0.7462
#
# Epoch 00063: val_acc did not improve from 0.81000
# Epoch 64/150
#  - 79s - loss: 0.1806 - acc: 0.9294 - val_loss: 0.5935 - val_acc: 0.7569
#
# Epoch 00064: val_acc did not improve from 0.81000
# Epoch 65/150
#  - 78s - loss: 0.1684 - acc: 0.9328 - val_loss: 0.5701 - val_acc: 0.7744
#
# Epoch 00065: val_acc did not improve from 0.81000
# Epoch 66/150
#  - 78s - loss: 0.1675 - acc: 0.9334 - val_loss: 0.7317 - val_acc: 0.7275
#
# Epoch 00066: val_acc did not improve from 0.81000
# Epoch 67/150
#  - 78s - loss: 0.1555 - acc: 0.9397 - val_loss: 0.6483 - val_acc: 0.7594
#
# Epoch 00067: val_acc did not improve from 0.81000
# Epoch 68/150
#  - 79s - loss: 0.1677 - acc: 0.9359 - val_loss: 0.6931 - val_acc: 0.7544
#
# Epoch 00068: val_acc did not improve from 0.81000
# Epoch 69/150
#  - 77s - loss: 0.1529 - acc: 0.9387 - val_loss: 0.6364 - val_acc: 0.7706
#
# Epoch 00069: val_acc did not improve from 0.81000
# Epoch 70/150
#  - 78s - loss: 0.1609 - acc: 0.9391 - val_loss: 0.6379 - val_acc: 0.7588
#
# Epoch 00070: val_acc did not improve from 0.81000
# Epoch 71/150
#  - 78s - loss: 0.1504 - acc: 0.9406 - val_loss: 0.6496 - val_acc: 0.7488
#
# Epoch 00071: val_acc did not improve from 0.81000
# Epoch 72/150
#  - 78s - loss: 0.1472 - acc: 0.9419 - val_loss: 0.7185 - val_acc: 0.7500
#
# Epoch 00072: val_acc did not improve from 0.81000
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 73/150
#  - 77s - loss: 0.1633 - acc: 0.9334 - val_loss: 0.6449 - val_acc: 0.7650
#
# Epoch 00073: val_acc did not improve from 0.81000
# Epoch 74/150
#  - 78s - loss: 0.1602 - acc: 0.9350 - val_loss: 0.6960 - val_acc: 0.7462
#
# Epoch 00074: val_acc did not improve from 0.81000
# Epoch 75/150
#  - 78s - loss: 0.1589 - acc: 0.9397 - val_loss: 0.6055 - val_acc: 0.7712
#
# Epoch 00075: val_acc did not improve from 0.81000
# Epoch 76/150
#  - 78s - loss: 0.1578 - acc: 0.9406 - val_loss: 0.6717 - val_acc: 0.7562
#
# Epoch 00076: val_acc did not improve from 0.81000
# Epoch 77/150
#  - 78s - loss: 0.1628 - acc: 0.9372 - val_loss: 0.6857 - val_acc: 0.7406
#
# Epoch 00077: val_acc did not improve from 0.81000
# Epoch 78/150
#  - 78s - loss: 0.1422 - acc: 0.9466 - val_loss: 0.6885 - val_acc: 0.7475
#
# Epoch 00078: val_acc did not improve from 0.81000
# Epoch 79/150
#  - 79s - loss: 0.1533 - acc: 0.9419 - val_loss: 0.6582 - val_acc: 0.7512
#
# Epoch 00079: val_acc did not improve from 0.81000
# Epoch 80/150
#  - 79s - loss: 0.1751 - acc: 0.9300 - val_loss: 0.7110 - val_acc: 0.7375
#
# Epoch 00080: val_acc did not improve from 0.81000
# Epoch 81/150
#  - 78s - loss: 0.1490 - acc: 0.9444 - val_loss: 0.6775 - val_acc: 0.7462
#
# Epoch 00081: val_acc did not improve from 0.81000
# Epoch 82/150
#  - 79s - loss: 0.1527 - acc: 0.9431 - val_loss: 0.7091 - val_acc: 0.7450
#
# Epoch 00082: val_acc did not improve from 0.81000
# Epoch 83/150
#  - 80s - loss: 0.1614 - acc: 0.9381 - val_loss: 0.6925 - val_acc: 0.7481
#
# Epoch 00083: val_acc did not improve from 0.81000
# Epoch 84/150
#  - 80s - loss: 0.1544 - acc: 0.9413 - val_loss: 0.6521 - val_acc: 0.7594
#
# Epoch 00084: val_acc did not improve from 0.81000
# Epoch 85/150
#  - 78s - loss: 0.1544 - acc: 0.9391 - val_loss: 0.7169 - val_acc: 0.7425
#
# Epoch 00085: val_acc did not improve from 0.81000
# Epoch 86/150
#  - 78s - loss: 0.1595 - acc: 0.9363 - val_loss: 0.6487 - val_acc: 0.7669
#
# Epoch 00086: val_acc did not improve from 0.81000
# Epoch 87/150
#  - 79s - loss: 0.1668 - acc: 0.9397 - val_loss: 0.6716 - val_acc: 0.7638
#
# Epoch 00087: val_acc did not improve from 0.81000
# Epoch 88/150
#  - 78s - loss: 0.1530 - acc: 0.9397 - val_loss: 0.6519 - val_acc: 0.7475
#
# Epoch 00088: val_acc did not improve from 0.81000
# Epoch 89/150
#  - 78s - loss: 0.1681 - acc: 0.9337 - val_loss: 0.6827 - val_acc: 0.7512
#
# Epoch 00089: val_acc did not improve from 0.81000
# Epoch 90/150
#  - 78s - loss: 0.1575 - acc: 0.9356 - val_loss: 0.6894 - val_acc: 0.7419
#
# Epoch 00090: val_acc did not improve from 0.81000
# Epoch 91/150
#  - 79s - loss: 0.1719 - acc: 0.9328 - val_loss: 0.6740 - val_acc: 0.7662
#
# Epoch 00091: val_acc did not improve from 0.81000
# Epoch 92/150
#  - 78s - loss: 0.1570 - acc: 0.9387 - val_loss: 0.7015 - val_acc: 0.7450
#
# Epoch 00092: val_acc did not improve from 0.81000
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 93/150
#  - 78s - loss: 0.1531 - acc: 0.9378 - val_loss: 0.7231 - val_acc: 0.7425
#
# Epoch 00093: val_acc did not improve from 0.81000
# Epoch 94/150
#  - 78s - loss: 0.1388 - acc: 0.9441 - val_loss: 0.6692 - val_acc: 0.7569
#
# Epoch 00094: val_acc did not improve from 0.81000
# Epoch 95/150
#  - 79s - loss: 0.1501 - acc: 0.9416 - val_loss: 0.7052 - val_acc: 0.7400
#
# Epoch 00095: val_acc did not improve from 0.81000
# Epoch 96/150
#  - 78s - loss: 0.1591 - acc: 0.9356 - val_loss: 0.7194 - val_acc: 0.7462
#
# Epoch 00096: val_acc did not improve from 0.81000
# Epoch 97/150
#  - 78s - loss: 0.1505 - acc: 0.9422 - val_loss: 0.7389 - val_acc: 0.7400
#
# Epoch 00097: val_acc did not improve from 0.81000
# Epoch 98/150
#  - 78s - loss: 0.1479 - acc: 0.9441 - val_loss: 0.7316 - val_acc: 0.7294
#
# Epoch 00098: val_acc did not improve from 0.81000
# Epoch 99/150
#  - 78s - loss: 0.1540 - acc: 0.9425 - val_loss: 0.6974 - val_acc: 0.7550
#
# Epoch 00099: val_acc did not improve from 0.81000
# Epoch 100/150
#  - 78s - loss: 0.1356 - acc: 0.9509 - val_loss: 0.6517 - val_acc: 0.7569
#
# Epoch 00100: val_acc did not improve from 0.81000
# Epoch 101/150
#  - 78s - loss: 0.1664 - acc: 0.9337 - val_loss: 0.6338 - val_acc: 0.7688
#
# Epoch 00101: val_acc did not improve from 0.81000
# Epoch 102/150
#  - 78s - loss: 0.1558 - acc: 0.9437 - val_loss: 0.7092 - val_acc: 0.7331
#
# Epoch 00102: val_acc did not improve from 0.81000
# Epoch 103/150
#  - 79s - loss: 0.1552 - acc: 0.9341 - val_loss: 0.6653 - val_acc: 0.7538
#
# Epoch 00103: val_acc did not improve from 0.81000
# Epoch 104/150
#  - 77s - loss: 0.1607 - acc: 0.9419 - val_loss: 0.6488 - val_acc: 0.7638
#
# Epoch 00104: val_acc did not improve from 0.81000
# Epoch 105/150
#  - 78s - loss: 0.1583 - acc: 0.9359 - val_loss: 0.6661 - val_acc: 0.7550
#
# Epoch 00105: val_acc did not improve from 0.81000
# Epoch 106/150
#  - 78s - loss: 0.1578 - acc: 0.9391 - val_loss: 0.6966 - val_acc: 0.7381
#
# Epoch 00106: val_acc did not improve from 0.81000
# Epoch 107/150
#  - 78s - loss: 0.1485 - acc: 0.9444 - val_loss: 0.6797 - val_acc: 0.7494
#
# Epoch 00107: val_acc did not improve from 0.81000
# Epoch 108/150
#  - 77s - loss: 0.1424 - acc: 0.9491 - val_loss: 0.6623 - val_acc: 0.7550
#
# Epoch 00108: val_acc did not improve from 0.81000
# Epoch 109/150
#  - 78s - loss: 0.1515 - acc: 0.9456 - val_loss: 0.6956 - val_acc: 0.7581
#
# Epoch 00109: val_acc did not improve from 0.81000
# Epoch 110/150
#  - 78s - loss: 0.1575 - acc: 0.9428 - val_loss: 0.6864 - val_acc: 0.7488
#
# Epoch 00110: val_acc did not improve from 0.81000
# Epoch 111/150
#  - 76s - loss: 0.1542 - acc: 0.9406 - val_loss: 0.6789 - val_acc: 0.7581
#
# Epoch 00111: val_acc did not improve from 0.81000
# Epoch 112/150
#  - 77s - loss: 0.1441 - acc: 0.9444 - val_loss: 0.6608 - val_acc: 0.7556
#
# Epoch 00112: val_acc did not improve from 0.81000
#
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# Epoch 113/150
#  - 77s - loss: 0.1669 - acc: 0.9350 - val_loss: 0.6582 - val_acc: 0.7556
#
# Epoch 00113: val_acc did not improve from 0.81000
# Epoch 114/150
#  - 79s - loss: 0.1645 - acc: 0.9394 - val_loss: 0.7315 - val_acc: 0.7375
#
# Epoch 00114: val_acc did not improve from 0.81000
# Epoch 115/150
#  - 77s - loss: 0.1505 - acc: 0.9437 - val_loss: 0.6550 - val_acc: 0.7525
#
# Epoch 00115: val_acc did not improve from 0.81000
# Epoch 116/150
#  - 77s - loss: 0.1459 - acc: 0.9400 - val_loss: 0.6564 - val_acc: 0.7612
#
# Epoch 00116: val_acc did not improve from 0.81000
# Epoch 117/150
#  - 77s - loss: 0.1414 - acc: 0.9419 - val_loss: 0.6542 - val_acc: 0.7556
#
# Epoch 00117: val_acc did not improve from 0.81000
# Epoch 118/150
#  - 76s - loss: 0.1361 - acc: 0.9462 - val_loss: 0.7168 - val_acc: 0.7356
#
# Epoch 00118: val_acc did not improve from 0.81000
# Epoch 119/150
#  - 73s - loss: 0.1554 - acc: 0.9431 - val_loss: 0.6828 - val_acc: 0.7381
#
# Epoch 00119: val_acc did not improve from 0.81000
# Epoch 120/150
#  - 73s - loss: 0.1596 - acc: 0.9363 - val_loss: 0.6777 - val_acc: 0.7581
#
# Epoch 00120: val_acc did not improve from 0.81000
# Epoch 121/150
#  - 73s - loss: 0.1543 - acc: 0.9403 - val_loss: 0.6949 - val_acc: 0.7412
#
# Epoch 00121: val_acc did not improve from 0.81000
# Epoch 122/150
#  - 74s - loss: 0.1582 - acc: 0.9394 - val_loss: 0.7122 - val_acc: 0.7462
#
# Epoch 00122: val_acc did not improve from 0.81000
# Epoch 123/150
#  - 73s - loss: 0.1501 - acc: 0.9419 - val_loss: 0.7313 - val_acc: 0.7344
#
# Epoch 00123: val_acc did not improve from 0.81000
# Epoch 124/150
#  - 72s - loss: 0.1616 - acc: 0.9359 - val_loss: 0.6905 - val_acc: 0.7594
#
# Epoch 00124: val_acc did not improve from 0.81000
# Epoch 125/150
#  - 70s - loss: 0.1486 - acc: 0.9434 - val_loss: 0.7113 - val_acc: 0.7469
#
# Epoch 00125: val_acc did not improve from 0.81000
# Epoch 126/150
#  - 71s - loss: 0.1632 - acc: 0.9381 - val_loss: 0.6334 - val_acc: 0.7581
#
# Epoch 00126: val_acc did not improve from 0.81000
# Epoch 127/150
#  - 72s - loss: 0.1418 - acc: 0.9434 - val_loss: 0.6960 - val_acc: 0.7481
#
# Epoch 00127: val_acc did not improve from 0.81000
# Epoch 128/150
#  - 71s - loss: 0.1519 - acc: 0.9422 - val_loss: 0.7516 - val_acc: 0.7431
#
# Epoch 00128: val_acc did not improve from 0.81000
# Epoch 129/150
#  - 71s - loss: 0.1632 - acc: 0.9353 - val_loss: 0.7178 - val_acc: 0.7531
#
# Epoch 00129: val_acc did not improve from 0.81000
# Epoch 130/150
#  - 71s - loss: 0.1366 - acc: 0.9475 - val_loss: 0.7234 - val_acc: 0.7538
#
# Epoch 00130: val_acc did not improve from 0.81000
# Epoch 131/150
#  - 72s - loss: 0.1462 - acc: 0.9431 - val_loss: 0.6882 - val_acc: 0.7525
#
# Epoch 00131: val_acc did not improve from 0.81000
# Epoch 132/150
#  - 71s - loss: 0.1549 - acc: 0.9369 - val_loss: 0.7316 - val_acc: 0.7331
#
# Epoch 00132: val_acc did not improve from 0.81000
#
# Epoch 00132: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# Epoch 133/150
#  - 71s - loss: 0.1548 - acc: 0.9431 - val_loss: 0.6366 - val_acc: 0.7669
#
# Epoch 00133: val_acc did not improve from 0.81000
# Epoch 134/150
#  - 70s - loss: 0.1621 - acc: 0.9369 - val_loss: 0.6725 - val_acc: 0.7581
#
# Epoch 00134: val_acc did not improve from 0.81000
# Epoch 135/150
#  - 72s - loss: 0.1640 - acc: 0.9384 - val_loss: 0.6542 - val_acc: 0.7612
#
# Epoch 00135: val_acc did not improve from 0.81000
# Epoch 136/150
#  - 71s - loss: 0.1415 - acc: 0.9475 - val_loss: 0.7341 - val_acc: 0.7281
#
# Epoch 00136: val_acc did not improve from 0.81000
# Epoch 137/150
#  - 71s - loss: 0.1641 - acc: 0.9384 - val_loss: 0.6856 - val_acc: 0.7481
#
# Epoch 00137: val_acc did not improve from 0.81000
# Epoch 138/150
#  - 70s - loss: 0.1577 - acc: 0.9413 - val_loss: 0.6947 - val_acc: 0.7506
#
# Epoch 00138: val_acc did not improve from 0.81000
# Epoch 139/150
#  - 71s - loss: 0.1462 - acc: 0.9453 - val_loss: 0.6593 - val_acc: 0.7569
#
# Epoch 00139: val_acc did not improve from 0.81000
# Epoch 140/150
#  - 70s - loss: 0.1556 - acc: 0.9413 - val_loss: 0.6723 - val_acc: 0.7631
#
# Epoch 00140: val_acc did not improve from 0.81000
# Epoch 141/150
#  - 70s - loss: 0.1534 - acc: 0.9403 - val_loss: 0.7123 - val_acc: 0.7362
#
# Epoch 00141: val_acc did not improve from 0.81000
# Epoch 142/150
#  - 71s - loss: 0.1525 - acc: 0.9394 - val_loss: 0.7094 - val_acc: 0.7394
#
# Epoch 00142: val_acc did not improve from 0.81000
# Epoch 143/150
#  - 71s - loss: 0.1407 - acc: 0.9487 - val_loss: 0.6886 - val_acc: 0.7500
#
# Epoch 00143: val_acc did not improve from 0.81000
# Epoch 144/150
#  - 72s - loss: 0.1615 - acc: 0.9378 - val_loss: 0.6831 - val_acc: 0.7619
#
# Epoch 00144: val_acc did not improve from 0.81000
# Epoch 145/150
#  - 71s - loss: 0.1660 - acc: 0.9366 - val_loss: 0.6638 - val_acc: 0.7562
#
# Epoch 00145: val_acc did not improve from 0.81000
# Epoch 146/150
#  - 72s - loss: 0.1639 - acc: 0.9394 - val_loss: 0.6568 - val_acc: 0.7494
#
# Epoch 00146: val_acc did not improve from 0.81000
# Epoch 147/150
#  - 72s - loss: 0.1513 - acc: 0.9419 - val_loss: 0.6845 - val_acc: 0.7625
#
# Epoch 00147: val_acc did not improve from 0.81000
# Epoch 148/150
#  - 72s - loss: 0.1485 - acc: 0.9444 - val_loss: 0.6820 - val_acc: 0.7531
#
# Epoch 00148: val_acc did not improve from 0.81000
# Epoch 149/150
#  - 73s - loss: 0.1485 - acc: 0.9469 - val_loss: 0.7097 - val_acc: 0.7531
#
# Epoch 00149: val_acc did not improve from 0.81000
# Epoch 150/150
#  - 72s - loss: 0.1576 - acc: 0.9375 - val_loss: 0.7102 - val_acc: 0.7669
#
# Epoch 00150: val_acc did not improve from 0.81000

# %%
test_path = "../input/test/"


def chunker(seq, size=32):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))


from tqdm import tqdm

submission = pd.read_csv('../input/sample_submission.csv')

predictions = []

for batch in tqdm(chunker(submission.img_pair.values)):
    X1 = [x.split("-")[0] for x in batch]
    X1 = np.array([read_img(test_path + x) for x in X1])

    X2 = [x.split("-")[1] for x in batch]
    X2 = np.array([read_img(test_path + x) for x in X2])

    pred = model.predict([X1, X2]).ravel().tolist()
    predictions += pred

submission['is_related'] = predictions

submission.to_csv("vgg_face_224_b_F09.csv", index=False)
# Out:
# 166it [01:12,  2.06it/s]

# %% [markdown]
# ## REFERENCE:
# [Kind of solutions](https://www.kaggle.com/c/recognizing-faces-in-the-wild/discussion/93263#latest-547742)
# [Code sharing - 0.81 LB](https://www.kaggle.com/c/recognizing-faces-in-the-wild/discussion/92454#latest-547744)
